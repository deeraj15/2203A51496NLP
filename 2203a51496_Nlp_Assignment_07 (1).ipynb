# %% [markdown]
# (a) Data Preprocessing

# %%
# Step 1: Install TensorFlow and necessary libraries
# !pip install tensorflow numpy

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example data (small English to French pairs)
data = [("hello", "bonjour"),
        ("how are you", "comment ça va"),
        ("I am fine", "je vais bien"),
        ("what is your name", "comment tu t'appelles"),
        ("my name is", "je m'appelle"),
        ("thank you", "merci"),
        ("goodbye", "au revoir")]

# Splitting the data into input (English) and output (French) pairs
english_sentences, french_sentences = zip(*data)

# Tokenize English sentences
eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english_sentences)
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
eng_word_index = eng_tokenizer.word_index
max_eng_len = max(len(seq) for seq in eng_sequences)

# Tokenize French sentences
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# Vocabulary sizes
eng_vocab_size = len(eng_word_index) + 1
fr_vocab_size = len(fr_word_index) + 1
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# (b) Build Seq2Seq Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Encoder
latent_dim = 256

encoder_inputs = Input(shape=(max_eng_len,))
enc_emb = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)

encoder_lstm = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(max_fr_len,))
dec_emb_layer = Embedding(fr_vocab_size, latent_dim)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)

decoder_dense = Dense(fr_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 4)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 3)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding (Embedding)     │ (None, 4, 256)         │          3,840 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, 3, 256)         │          3,584 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm (LSTM)               │ [(None, 256), (None,   │        525,312 │ embedding[0][0]        │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_1 (LSTM)             │ [(None, 3, 256),       │        525,312 │ embedding_1[0][0],     │
# │                           │ (None, 256), (None,    │                │ lstm[0][1], lstm[0][2] │
# │                           │ 256)]                  │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 3, 14)          │          3,598 │ lstm_1[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,061,646 (4.05 MB)
#  Trainable params: 1,061,646 (4.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# (c) Preparing the Data for Training

# %%
# Preparing decoder target data (shifted French sentences)
fr_padded_target = np.zeros_like(fr_padded)
fr_padded_target[:, :-1] = fr_padded[:, 1:]

# Train/Val Split
train_size = int(0.8 * len(eng_padded))
eng_train, eng_val = eng_padded[:train_size], eng_padded[train_size:]
fr_train, fr_val = fr_padded[:train_size], fr_padded[train_size:]
fr_target_train, fr_target_val = fr_padded_target[:train_size], fr_padded_target[train_size:]

# %% [markdown]
# (d) Train the Model on the Dataset

# %%
batch_size = 64
epochs = 100

history = model.fit([eng_train, fr_train], fr_target_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.1333 - loss: 2.6343 - val_accuracy: 0.8333 - val_loss: 2.5720
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6000 - loss: 2.5883 - val_accuracy: 0.8333 - val_loss: 2.5100
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6000 - loss: 2.5392 - val_accuracy: 0.8333 - val_loss: 2.4352
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5333 - loss: 2.4821 - val_accuracy: 0.8333 - val_loss: 2.3400
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5333 - loss: 2.4118 - val_accuracy: 0.8333 - val_loss: 2.2157
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 2.3225 - val_accuracy: 0.8333 - val_loss: 2.0522
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 2.2075 - val_accuracy: 0.8333 - val_loss: 1.8395
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 2.0603 - val_accuracy: 0.8333 - val_loss: 1.5734
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5333 - loss: 1.8787 - val_accuracy: 0.8333 - val_loss: 1.2752
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.6761 - val_accuracy: 0.8333 - val_loss: 1.0222
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.4934 - val_accuracy: 0.8333 - val_loss: 0.9158
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5333 - loss: 1.4002 - val_accuracy: 0.8333 - val_loss: 0.9638
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5333 - loss: 1.4370 - val_accuracy: 0.8333 - val_loss: 1.0502
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 1.4857 - val_accuracy: 0.8333 - val_loss: 1.0952
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.4574 - val_accuracy: 0.8333 - val_loss: 1.0974
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 1.3724 - val_accuracy: 0.8333 - val_loss: 1.0761
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5333 - loss: 1.2746 - val_accuracy: 0.8333 - val_loss: 1.0501
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5333 - loss: 1.1961 - val_accuracy: 0.8333 - val_loss: 1.0320
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5333 - loss: 1.1476 - val_accuracy: 0.8333 - val_loss: 1.0265
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 1.1227 - val_accuracy: 0.8333 - val_loss: 1.0320
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5333 - loss: 1.1072 - val_accuracy: 0.8333 - val_loss: 1.0442
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 1.0888 - val_accuracy: 0.8333 - val_loss: 1.0598
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.6000 - loss: 1.0602 - val_accuracy: 0.8333 - val_loss: 1.0777
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6000 - loss: 1.0193 - val_accuracy: 0.8333 - val_loss: 1.0992
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6667 - loss: 0.9671 - val_accuracy: 0.8333 - val_loss: 1.1269
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6667 - loss: 0.9073 - val_accuracy: 0.8333 - val_loss: 1.1636
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6667 - loss: 0.8446 - val_accuracy: 0.8333 - val_loss: 1.2108
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6667 - loss: 0.7839 - val_accuracy: 0.8333 - val_loss: 1.2684
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6667 - loss: 0.7276 - val_accuracy: 0.8333 - val_loss: 1.3339
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6667 - loss: 0.6755 - val_accuracy: 0.8333 - val_loss: 1.4031
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6667 - loss: 0.6248 - val_accuracy: 0.8333 - val_loss: 1.4717
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8667 - loss: 0.5723 - val_accuracy: 0.8333 - val_loss: 1.5364
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9333 - loss: 0.5170 - val_accuracy: 0.8333 - val_loss: 1.5963
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9333 - loss: 0.4607 - val_accuracy: 0.8333 - val_loss: 1.6531
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.4078 - val_accuracy: 0.8333 - val_loss: 1.7109
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.3625 - val_accuracy: 0.8333 - val_loss: 1.7754
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.3248 - val_accuracy: 0.8333 - val_loss: 1.8521
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.2891 - val_accuracy: 0.8333 - val_loss: 1.9435
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.2520 - val_accuracy: 0.8333 - val_loss: 2.0481
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.2174 - val_accuracy: 0.8333 - val_loss: 2.1619
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.1885 - val_accuracy: 0.8333 - val_loss: 2.2797
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.1651 - val_accuracy: 0.8333 - val_loss: 2.3959
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.1456 - val_accuracy: 0.8333 - val_loss: 2.5060
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.1278 - val_accuracy: 0.8333 - val_loss: 2.6078
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.1110 - val_accuracy: 0.8333 - val_loss: 2.7008
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0959 - val_accuracy: 0.8333 - val_loss: 2.7862
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0832 - val_accuracy: 0.8333 - val_loss: 2.8660
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0733 - val_accuracy: 0.8333 - val_loss: 2.9426
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0649 - val_accuracy: 0.8333 - val_loss: 3.0174
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0566 - val_accuracy: 0.8333 - val_loss: 3.0899
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0492 - val_accuracy: 0.8333 - val_loss: 3.1584
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0434 - val_accuracy: 0.8333 - val_loss: 3.2219
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0385 - val_accuracy: 0.8333 - val_loss: 3.2799
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0340 - val_accuracy: 0.8333 - val_loss: 3.3320
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 0.8333 - val_loss: 3.3781
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.8333 - val_loss: 3.4183
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 0.8333 - val_loss: 3.4530
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.8333 - val_loss: 3.4827
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.8333 - val_loss: 3.5084
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.8333 - val_loss: 3.5309
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.8333 - val_loss: 3.5512
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.8333 - val_loss: 3.5697
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.8333 - val_loss: 3.5869
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.8333 - val_loss: 3.6027
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.8333 - val_loss: 3.6174
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8333 - val_loss: 3.6311
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8333 - val_loss: 3.6438
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.8333 - val_loss: 3.6559
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8333 - val_loss: 3.6674
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8333 - val_loss: 3.6783
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8333 - val_loss: 3.6886
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8333 - val_loss: 3.6983
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8333 - val_loss: 3.7074
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8333 - val_loss: 3.7158
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8333 - val_loss: 3.7236
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8333 - val_loss: 3.7308
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8333 - val_loss: 3.7375
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8333 - val_loss: 3.7436
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8333 - val_loss: 3.7492
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8333 - val_loss: 3.7543
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8333 - val_loss: 3.7589
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8333 - val_loss: 3.7631
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8333 - val_loss: 3.7670
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8333 - val_loss: 3.7706
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8333 - val_loss: 3.7740
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 3.7772
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8333 - val_loss: 3.7804
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8333 - val_loss: 3.7836
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8333 - val_loss: 3.7867
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.7897
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8333 - val_loss: 3.7926
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.7955
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.7983
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.8009
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 3.8033
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 3.8056
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 3.8077
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8333 - val_loss: 3.8097
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.8114
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.8130

# %% [markdown]
# (e) Inference Setup for Translation

# %%
# Inference Encoder
encoder_model = Model(encoder_inputs, encoder_states)

# Inference Decoder
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2 = dec_emb_layer(decoder_inputs)

decoder_outputs2, state_h2, state_c2 = decoder_lstm(
    dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)

decoder_model = Model([decoder_inputs] + decoder_states_inputs,
                      [decoder_outputs2] + decoder_states2)

# %% [markdown]
# (f) Translate New Sentences

# %%
# Add 'start' and 'end' tokens to French sentences
french_sentences_with_tokens = ['start ' + sent + ' end' for sent in french_sentences]

# Tokenize French sentences with start and end tokens
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences_with_tokens)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences_with_tokens)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        if sampled_word == 'end' or len(decoded_sentence) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]

    return decoded_sentence

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Get the index of the most likely next word
        sampled_token_index = np.argmax(output_tokens[0, -1, :])

        # Retrieve the corresponding word for the token index
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        # Handle the case where the word is not found
        if sampled_word is None:
            print(f"Warning: No word found for token index {sampled_token_index}")
            stop_condition = True
        elif sampled_word == 'end' or len(decoded_sentence.split()) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        # Update the target sequence to the predicted word
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states for the next iteration
        states_value = [h, c]

    return decoded_sentence

# %%
# Testing with a new sentence
test_sentence = "hello"
test_sequence = eng_tokenizer.texts_to_sequences([test_sentence])
test_sequence = pad_sequences(test_sequence, maxlen=max_eng_len, padding='post')

translation = decode_sequence(test_sequence)
print(f"Translation: {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Warning: No word found for token index 0
# Translation:

# %% [markdown]
# (g) Experimenting and Improving the Model with a Larger Dataset

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import Adam

# Define the latent_dim and other hyperparameters
latent_dim = 256
eng_vocab_size = 15  # Example value; replace with actual vocab size
fr_vocab_size = 15   # Example value; replace with actual vocab size
embedding_dim = 128  # Size of the embedding vectors

# Define encoder
encoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
encoder_embedding = Embedding(input_dim=eng_vocab_size, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_sequences=True)(encoder_embedding)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_lstm)
encoder_states = [state_h, state_c]

# Define decoder
decoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
decoder_embedding = Embedding(input_dim=fr_vocab_size, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True)(decoder_embedding, initial_state=encoder_states)
decoder_outputs = Dense(fr_vocab_size, activation='softmax')(decoder_lstm)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
opt = Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Check the shapes of the training data
# Ensure eng_train, fr_train, and fr_target_train have the appropriate shapes
print(f"eng_train shape: {eng_train.shape}, fr_train shape: {fr_train.shape}, fr_target_train shape: {fr_target_train.shape}")

# Train the model
model.fit([eng_train, fr_train], fr_target_train, batch_size=batch_size, epochs=200, validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# eng_train shape: (5, 4), fr_train shape: (5, 3), fr_target_train shape: (5, 3)
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.0000e+00 - loss: 2.7091 - val_accuracy: 0.8333 - val_loss: 2.6931
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5333 - loss: 2.6964 - val_accuracy: 0.8333 - val_loss: 2.6772
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 2.6833 - val_accuracy: 0.8333 - val_loss: 2.6596
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 2.6692 - val_accuracy: 0.8333 - val_loss: 2.6395
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 2.6534 - val_accuracy: 0.8333 - val_loss: 2.6159
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 2.6353 - val_accuracy: 0.8333 - val_loss: 2.5876
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 2.6141 - val_accuracy: 0.8333 - val_loss: 2.5533
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5333 - loss: 2.5889 - val_accuracy: 0.8333 - val_loss: 2.5113
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5333 - loss: 2.5584 - val_accuracy: 0.8333 - val_loss: 2.4596
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 2.5213 - val_accuracy: 0.8333 - val_loss: 2.3956
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.5333 - loss: 2.4758 - val_accuracy: 0.8333 - val_loss: 2.3164
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.5333 - loss: 2.4196 - val_accuracy: 0.8333 - val_loss: 2.2183
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5333 - loss: 2.3501 - val_accuracy: 0.8333 - val_loss: 2.0970
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.5333 - loss: 2.2643 - val_accuracy: 0.8333 - val_loss: 1.9481
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5333 - loss: 2.1590 - val_accuracy: 0.8333 - val_loss: 1.7683
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5333 - loss: 2.0325 - val_accuracy: 0.8333 - val_loss: 1.5589
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5333 - loss: 1.8870 - val_accuracy: 0.8333 - val_loss: 1.3329
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 1.7348 - val_accuracy: 0.8333 - val_loss: 1.1245
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 1.6045 - val_accuracy: 0.8333 - val_loss: 0.9834
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 1.5421 - val_accuracy: 0.8333 - val_loss: 0.9395
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.5730 - val_accuracy: 0.8333 - val_loss: 0.9584
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 1.6334 - val_accuracy: 0.8333 - val_loss: 0.9832
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5333 - loss: 1.6484 - val_accuracy: 0.8333 - val_loss: 0.9938
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5333 - loss: 1.6106 - val_accuracy: 0.8333 - val_loss: 0.9927
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5333 - loss: 1.5443 - val_accuracy: 0.8333 - val_loss: 0.9887
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5333 - loss: 1.4756 - val_accuracy: 0.8333 - val_loss: 0.9892
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 1.4222 - val_accuracy: 0.8333 - val_loss: 0.9981
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 1.3907 - val_accuracy: 0.8333 - val_loss: 1.0145
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5333 - loss: 1.3777 - val_accuracy: 0.8333 - val_loss: 1.0346
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 1.3755 - val_accuracy: 0.8333 - val_loss: 1.0537
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 1.3759 - val_accuracy: 0.8333 - val_loss: 1.0684
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5333 - loss: 1.3734 - val_accuracy: 0.8333 - val_loss: 1.0776
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5333 - loss: 1.3649 - val_accuracy: 0.8333 - val_loss: 1.0818
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5333 - loss: 1.3499 - val_accuracy: 0.8333 - val_loss: 1.0833
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 1.3291 - val_accuracy: 0.8333 - val_loss: 1.0850
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5333 - loss: 1.3046 - val_accuracy: 0.8333 - val_loss: 1.0898
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.5333 - loss: 1.2789 - val_accuracy: 0.8333 - val_loss: 1.1004
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5333 - loss: 1.2545 - val_accuracy: 0.8333 - val_loss: 1.1179
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.5333 - loss: 1.2338 - val_accuracy: 0.8333 - val_loss: 1.1424
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5333 - loss: 1.2178 - val_accuracy: 0.8333 - val_loss: 1.1723
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.5333 - loss: 1.2061 - val_accuracy: 0.8333 - val_loss: 1.2050
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.5333 - loss: 1.1969 - val_accuracy: 0.8333 - val_loss: 1.2373
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.5333 - loss: 1.1877 - val_accuracy: 0.8333 - val_loss: 1.2667
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 1.1761 - val_accuracy: 0.8333 - val_loss: 1.2916
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.1613 - val_accuracy: 0.8333 - val_loss: 1.3119
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5333 - loss: 1.1436 - val_accuracy: 0.8333 - val_loss: 1.3284
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5333 - loss: 1.1243 - val_accuracy: 0.8333 - val_loss: 1.3427
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5333 - loss: 1.1052 - val_accuracy: 0.8333 - val_loss: 1.3566
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5333 - loss: 1.0876 - val_accuracy: 0.8333 - val_loss: 1.3717
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.0718 - val_accuracy: 0.8333 - val_loss: 1.3893
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5333 - loss: 1.0575 - val_accuracy: 0.8333 - val_loss: 1.4104
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5333 - loss: 1.0435 - val_accuracy: 0.8333 - val_loss: 1.4353
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5333 - loss: 1.0288 - val_accuracy: 0.8333 - val_loss: 1.4646
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5333 - loss: 1.0125 - val_accuracy: 0.8333 - val_loss: 1.4984
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5333 - loss: 0.9943 - val_accuracy: 0.8333 - val_loss: 1.5369
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 0.9743 - val_accuracy: 0.8333 - val_loss: 1.5801
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5333 - loss: 0.9533 - val_accuracy: 0.8333 - val_loss: 1.6275
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 0.9321 - val_accuracy: 0.8333 - val_loss: 1.6782
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5333 - loss: 0.9112 - val_accuracy: 0.8333 - val_loss: 1.7310
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 0.8906 - val_accuracy: 0.8333 - val_loss: 1.7843
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 0.8696 - val_accuracy: 0.8333 - val_loss: 1.8367
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5333 - loss: 0.8476 - val_accuracy: 0.8333 - val_loss: 1.8873
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5333 - loss: 0.8240 - val_accuracy: 0.8333 - val_loss: 1.9361
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5333 - loss: 0.7986 - val_accuracy: 0.8333 - val_loss: 1.9838
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6667 - loss: 0.7719 - val_accuracy: 0.8333 - val_loss: 2.0316
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6667 - loss: 0.7443 - val_accuracy: 0.8333 - val_loss: 2.0811
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7333 - loss: 0.7164 - val_accuracy: 0.8333 - val_loss: 2.1335
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9333 - loss: 0.6881 - val_accuracy: 0.8333 - val_loss: 2.1896
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9333 - loss: 0.6591 - val_accuracy: 0.6667 - val_loss: 2.2497
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9333 - loss: 0.6288 - val_accuracy: 0.6667 - val_loss: 2.3132
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9333 - loss: 0.5971 - val_accuracy: 0.6667 - val_loss: 2.3793
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9333 - loss: 0.5644 - val_accuracy: 0.6667 - val_loss: 2.4465
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9333 - loss: 0.5312 - val_accuracy: 0.6667 - val_loss: 2.5127
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9333 - loss: 0.4981 - val_accuracy: 0.6667 - val_loss: 2.5759
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9333 - loss: 0.4651 - val_accuracy: 0.6667 - val_loss: 2.6348
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9333 - loss: 0.4320 - val_accuracy: 0.6667 - val_loss: 2.6888
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9333 - loss: 0.3989 - val_accuracy: 0.6667 - val_loss: 2.7387
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.3664 - val_accuracy: 0.6667 - val_loss: 2.7861
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.3355 - val_accuracy: 0.6667 - val_loss: 2.8326
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.3065 - val_accuracy: 0.6667 - val_loss: 2.8794
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.2794 - val_accuracy: 0.6667 - val_loss: 2.9267
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.2538 - val_accuracy: 0.6667 - val_loss: 2.9740
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.2301 - val_accuracy: 0.6667 - val_loss: 3.0202
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.2087 - val_accuracy: 0.6667 - val_loss: 3.0640
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.1895 - val_accuracy: 0.6667 - val_loss: 3.1042
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 0.1721 - val_accuracy: 0.6667 - val_loss: 3.1404
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.1562 - val_accuracy: 0.6667 - val_loss: 3.1725
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.1417 - val_accuracy: 0.6667 - val_loss: 3.2013
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.1287 - val_accuracy: 0.6667 - val_loss: 3.2277
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.1172 - val_accuracy: 0.6667 - val_loss: 3.2523
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.1067 - val_accuracy: 0.6667 - val_loss: 3.2754
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0971 - val_accuracy: 0.6667 - val_loss: 3.2967
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0884 - val_accuracy: 0.6667 - val_loss: 3.3158
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0806 - val_accuracy: 0.6667 - val_loss: 3.3324
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0735 - val_accuracy: 0.6667 - val_loss: 3.3465
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0671 - val_accuracy: 0.6667 - val_loss: 3.3588
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0612 - val_accuracy: 0.6667 - val_loss: 3.3700
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0560 - val_accuracy: 0.6667 - val_loss: 3.3810
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0515 - val_accuracy: 0.6667 - val_loss: 3.3925
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0474 - val_accuracy: 0.6667 - val_loss: 3.4045
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0436 - val_accuracy: 0.6667 - val_loss: 3.4169
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0402 - val_accuracy: 0.6667 - val_loss: 3.4292
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0372 - val_accuracy: 0.6667 - val_loss: 3.4410
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0344 - val_accuracy: 0.6667 - val_loss: 3.4521
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.6667 - val_loss: 3.4623
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0297 - val_accuracy: 0.6667 - val_loss: 3.4717
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.6667 - val_loss: 3.4803
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.6667 - val_loss: 3.4881
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.6667 - val_loss: 3.4951
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.6667 - val_loss: 3.5015
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.6667 - val_loss: 3.5070
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.6667 - val_loss: 3.5117
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.0193 - val_accuracy: 0.6667 - val_loss: 3.5155
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.6667 - val_loss: 3.5185
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.6667 - val_loss: 3.5210
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.6667 - val_loss: 3.5229
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.6667 - val_loss: 3.5246
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.6667 - val_loss: 3.5260
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.6667 - val_loss: 3.5274
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.6667 - val_loss: 3.5288
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.6667 - val_loss: 3.5302
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.6667 - val_loss: 3.5319
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.6667 - val_loss: 3.5337
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.6667 - val_loss: 3.5357
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.6667 - val_loss: 3.5381
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.6667 - val_loss: 3.5406
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.6667 - val_loss: 3.5435
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.6667 - val_loss: 3.5465
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.6667 - val_loss: 3.5496
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.6667 - val_loss: 3.5528
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.6667 - val_loss: 3.5561
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.6667 - val_loss: 3.5594
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.6667 - val_loss: 3.5627
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.6667 - val_loss: 3.5660
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.6667 - val_loss: 3.5693
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.6667 - val_loss: 3.5725
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.6667 - val_loss: 3.5757
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.6667 - val_loss: 3.5787
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.6667 - val_loss: 3.5817
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.6667 - val_loss: 3.5845
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.6667 - val_loss: 3.5871
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.6667 - val_loss: 3.5897
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.6667 - val_loss: 3.5920
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.6667 - val_loss: 3.5943
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.6667 - val_loss: 3.5964
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.6667 - val_loss: 3.5985
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.6667 - val_loss: 3.6005
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.6667 - val_loss: 3.6024
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.6667 - val_loss: 3.6043
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.6667 - val_loss: 3.6062
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.6667 - val_loss: 3.6081
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.6667 - val_loss: 3.6100
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.6667 - val_loss: 3.6118
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6667 - val_loss: 3.6137
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.6667 - val_loss: 3.6155
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.6667 - val_loss: 3.6173
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.6667 - val_loss: 3.6191
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.6667 - val_loss: 3.6209
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.6667 - val_loss: 3.6227
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.6667 - val_loss: 3.6245
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6667 - val_loss: 3.6262
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6667 - val_loss: 3.6280
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6667 - val_loss: 3.6298
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.6667 - val_loss: 3.6316
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6667 - val_loss: 3.6333
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6667 - val_loss: 3.6350
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.6667 - val_loss: 3.6367
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.6667 - val_loss: 3.6384
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.6667 - val_loss: 3.6400
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6667 - val_loss: 3.6416
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6667 - val_loss: 3.6432
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.6667 - val_loss: 3.6446
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6667 - val_loss: 3.6461
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6667 - val_loss: 3.6475
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6667 - val_loss: 3.6488
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6667 - val_loss: 3.6501
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6667 - val_loss: 3.6514
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6667 - val_loss: 3.6526
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.6667 - val_loss: 3.6537
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.6667 - val_loss: 3.6548
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.6667 - val_loss: 3.6559
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.6667 - val_loss: 3.6570
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6667 - val_loss: 3.6580
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6667 - val_loss: 3.6589
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6667 - val_loss: 3.6599
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6667 - val_loss: 3.6608
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6667 - val_loss: 3.6617
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6667 - val_loss: 3.6626
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6667 - val_loss: 3.6634
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6667 - val_loss: 3.6643
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6667 - val_loss: 3.6651
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6667 - val_loss: 3.6659
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 3.6667
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 3.6675
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 3.6683
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 3.6691
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 3.6699
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 3.6706
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 3.6714
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 3.6721
